# %%
# import packages

from IPython.display import Image, display_png
from rdkit.Chem.Draw import IPythonConsole

import metadisassembler as medi

# %% [markdown]
# ## Test1

# %%
test1 = medi.MetaDisassembler()
test1.input_query('C11815')
test1.cpds[0].mol

# %%
test1.disassemble()
# Out:
# Finished.
# True

# %%
display_png(Image('./output/' + test1.name + '/0.png'))

# %% [markdown]
# ## Test2

# %%
test2 = medi.MetaDisassembler()
test2.input_query('C20596')
test2.cpds[0].mol

# %%
test2.disassemble()
# Out:
# Finished.
# True

# %%
display_png(Image('./output/' + test2.name + '/0.png'))
